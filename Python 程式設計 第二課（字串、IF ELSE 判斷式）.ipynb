# %% [markdown]
# # Dunning-Kruger Effect（達克效應）
#
#
# ![](https://drive.google.com/uc?export=download&id=16x7afQuI5s3zKSGB7n6yA7U7OqzLMTk_)
#
# ---
# # 不知道自己不知道，是一個很可怕的狀態
#
# # 進步使人謙虛，落後使人驕傲
#
# ---
# # 達克效應
# 延申閲讀：[Wikipedia](https://zh.wikipedia.org/wiki/%E8%BE%BE%E5%85%8B%E6%95%88%E5%BA%94)
#
# ---

# %% [markdown]
# # 資料型別（Data Types）
#
# 今天我們在寫程式，目的不外乎是爲了用電腦自動化現實生活中的人事物以及流程
#
# 一個程式語言會有許多不同的資料型別（Data Types）
#
# ---
# # 資料型別（Data Types）
#
# - 舉例來説，**一個人的歲數是用整數來表示**
#
# - 但是，一個人的體重則是用**帶有小數點的數字來表示**
#
# - 相對的，一個人的名字則是可以用**一連串的文字，也就是字串來表示**
#
# ---
# # 資料型別（Data Types）
#
# 一些我們之前見識過的資料型別：
#
# - 數值
# 	- int (整數)
# 	- float (浮點數)
# - 字串 (str)
#
# ---
# # 若需要檢查變數的資料型別
#
# 可以使用 `type()` 函數
#
# ```python
# height = 180
# type(height)
# # int
#
# weight = 70.8
# type(weight)
# # float
#
# name = "John"
# type(name)
# # str
# ```

# %%
height = 180
print('height:',height)
print(type(height))
# int
weight = 70.8
print('weight:',weight)
print(type(weight))
# float
name = "John"
print('name:',name )
print(type(name))
# str
# Out:
# height: 180
# <class 'int'>
# weight: 70.8
# <class 'float'>
# name: John
# <class 'str'>

# %% [markdown]
# # 我們來嘗試計算自己距離 200 公分的差距
#
# 當我們嘗試把一個整數和字串用 `+` 串在一起時：
#
# ```python
# my_height = input()
# print("你距離 200 公分有：" + (200 - my_height) + "公分！")
# # TypeError: must be str, not int
# ```
#
# 因為**資料型別的不同**，無法把**字串與整數相減**
#
# ```python
# # 一個整數不可能與一段文字相減
# 200 - "180"
# ```

# %% [markdown]
# # 型別轉換（Type Conversion）
#
# 若是用 `int()` 函式先將 `my_height` 變數的資料型別從字串轉成整數，就可
# 計算 `my_height` 與 `200` 的差距，但是接下來依然還是會出錯，原因在於被計算出來的差距為一個數字，無法與其他字串做相加：
#
#
# ```python
# my_height = input()
# print("你距離 200 公分有：" + (200 - int(my_height)) + "公分！")
# ```
#
# ---
# # 型別轉換（Type Conversion）
#
# 因此，我們可以用 `str()` 函數將算出來的差距轉換成字串，才能將這三個字串串連起來並顯示：
#
# ```python
# my_height = input()
# print("你距離 200 公分有：" + str(200 - int(my_height)) + "公分！")
# ```
#
# ---

# %%
my_height = input()
print("你距離 200 公分有：" + str(200 - int(my_height)) + "公分！")
# Out:
# 你距離 200 公分有：20公分！

# %% [markdown]
# # 一些常見的型別轉換函數
#
# ```python
# # 設定 num_str 變數為字串 "123"
# num_str = "123"
# # 印出來的結果看起來像 123
# print(num_str)
# # 但實際上資料型別是 str
# print(type(num_str))
#
# # 將字串 "123" 轉換型別，變成整數 123
# num = int(num_str)
# # 印出來的結果看起來也是 123
# print(num)
# # 但實際上資料型別是 int
# print(type(num))
#
# # 用 float() 函數將字串 "123" 轉成浮點數 123.0
# num_float = float(num_str)
# # 印出來的結果是 123.0
# print(num_float)
# # 資料型別是 float
# print(type(num_float))
# ```

# %%
# 設定 num_str 變數為字串 "123"
num_str = "123"
# 印出來的結果看起來像 123
print(num_str)
# 但實際上資料型別是 str
print(type(num_str))

# 將字串 "123" 轉換型別，變成整數 123
num = int(num_str)
# 印出來的結果看起來也是 123
print(num)
# 但實際上資料型別是 int
print(type(num))

# 用 float() 函數將字串 "123" 轉成浮點數 123.0
num_float = float(num_str)
# 印出來的結果是 123.0
print(num_float)
# 資料型別是 float
print(type(num_float))
# Out:
# 123
# <class 'str'>
# 123
# <class 'int'>
# 123.0
# <class 'float'>

# %% [markdown]
# # 字串（String）
#
# 來看另一種資料型別，字串：
#
#
# ```python
# # 字串可用**單引號**或**雙引號**宣告，只要兩段一致即可
# str1 = "Hello World!!!"
# str2 = 'Hello World!!!'
# ```

# %% [markdown]
# # 字串（String）
#
# 當你需要在字串內使用單引號或雙引號時...
# ```python
# str_error = 'It's a wonderful world!'
# ```
# 就會出現錯誤，為了避免該問題，可用 \ 規避符號 (escape character)
# ```python
# str_error = 'It\'s a wonderful world!'
# ```

# %%
str_error = 'It\'s a wonderful world!'
str_error
# Out:
# "It's a wonderful world!"

# %% [markdown]
# # 字串（String）
#
# 我們再來看另一個例子：
# ```python
# str_error = "The following is a quote: "A quote inside string""
# str_error = "The following is a quote: \"A quote inside string\""
# ```

# %%
str_error = "The following is a quote: \"A quote inside string\""
str_error
# Out:
# 'The following is a quote: "A quote inside string"'

# %% [markdown]
# # 提取子元
# 今天如果我們想提取一個字串個別的字元
#
# # 提取子元
#
# 在 Python，字串是一個序列，每一個子元都有編上一個代表順序的號碼（索引值）：
#
# | 字串   | P   | Y   | T   | H   | O   | N   |
# | ------ | --- | --- | --- | --- | --- | --- |
# | 索引值 | 0   | 1   | 2   | 3   | 4   | 5   |
#
# ```python
# "PYTHON"[0]
# # 會回傳 "P"
# "PYTHON"[5]
# # 會回傳 "N"
# ```

# %% [markdown]
# # 字串切片（Slice）
#
# 從一個字串中截取一段**子字串（substring）**
#
# 舉例來説，我們想把 "PYTHON" 這個字串的前三個文字截取下來：
#
# ```python
# "PYTHON"[0:3]
# # "PYT"
# ```

# %%
"PYTHON"[0:3]
# Out:
# 'PYT'

# %% [markdown]
# # 字串切片（Slice)
#
# 一些常用的切片語法：
#
#
# - `[:]`：會截取整個字串，從開始到結束
# - `[ start :]`：會從 start 所對應的字符開始，到字串結尾截取下來
# - `[ : end ]`：會從字串一開始到 end 所對應的前一個字符爲止截取下來
# - `[ start : end ]` ： 會從 start 所對應的字符開始，到 end 所對應的前一個字符爲止取下來 |
# - `[ start : end : step ]` ： 會從 start 所對應的字符開始，到字串結尾截取下來
#
# ```python
# "PYTHON"[:]
# # "PYTHON"
#
# "PYTHON"[3:]
# # "HON"
#
# "PYTHON"[:3]
# # "PYT"
#
# "PYTHON"[1:3]
# # "YT"
#
# "PYTHOH"[0:5:2]
# # PTO
# ```

# %%
"PYTHON"[:]
# "PYTHON"

"PYTHON"[3:]
# "HON"

"PYTHON"[:3]
# "PYT"

"PYTHON"[1:3]
# "YT"

"PYTHOH"[0:5:2]
# PTO
# Out:
# 'PTO'

# %% [markdown]
# # 常用的字串方法
#
# # str.split()
#
# 以空白符號，將字串分切成多個子字串
#
# ```python
# split_result = "My name is Eugene".split()
# print(split_result)
# # ['My', 'name', 'is', 'Eugene']
# ```

# %%
split_result = "My name is Eugene".split()
print(split_result)
# Out:
# ['My', 'name', 'is', 'Eugene']

# %% [markdown]
# # str.capitalize()
#
# 將字串内的第一個字母變成大寫
#
# ```python
# str_1 = "python"
#
# str_1.capitalize()
# # 'Python'
# ```

# %%
str_1 = "python"

str_1.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # Dot Notation（句點表示法）
#
# ```python
# <物件名稱>.<屬性名稱> = 值
# ```
#
# **逗點 *可以想象成中文 `的`**
#
#
# ```python
# str_1.capitalize()
# ```
# 就代表要針對 **str_1** 這個字串使用 `.captialize()` 這個方法 (method)
#
# # method (方法)
#
# 可以想象成**某一種資料型別獨有的函數/功能**
#
# 以我們剛才學會的 `.captialize()` 爲例，把第一個字母變大寫是字串獨有的功能，你無法把數字變大寫，所以 `.captialize()` 就是**字串獨有的功能**

# %% [markdown]
# # str.join()
#
# 用某個字符，將多個字串結合起來
#
# 給予三個字串：
# ```python
# str_1 = "I"
# str_2 = "am"
# str_3 = "Ironman"
# ```
#
# 把這三個字串用空白符號 " " 串接起來：
#
# ```python
# " ".join([str_1, str_2, str_3])
# # 'I am Ironman'
# ```
#
# 若沒有指定任何字符，就會變成：
# ```python
# "".join([str_1, str_2, str_3])
# # 'IamIronman'
# ```

# %%
str_1 = "I"
str_2 = "am"
str_3 = "Ironman"
print(" ".join([str_1, str_2, str_3]))
# 'I am Ironman'
print("".join([str_1, str_2, str_3]))
# 'IamIronman'
# Out:
# I am Ironman
# IamIronman

# %% [markdown]
# # str.replace()
# 將字串内某一個字串改成另一個字串
#
# ```python
# cipher = "KELLR SYTHRN!"
# cipher.replace("K", "H")
# # HXYZllo thXYZrXYZ!
# ```

# %%
cipher = "KELLR SYTHRN!"
cipher.replace("K", "H")
# Out:
# 'HELLR SYTHRN!'

# %% [markdown]
# # 隨堂練習 1
#
# 給予一個字串 `"123,456,789"`
#
# 請用 Python 將這個字串轉換成浮點數 `123456789.0`

# %%
float(123456789)
# Out:
# 123456789.0

# %% [markdown]
# # 隨堂練習 2：凱撒密碼
#
# 給予一個被凱撒密碼加密過的字串
#
# ```python
# cipher = "KELLR SYTHRN!"
# ```
#
# 請將 K, S, R 三個字母替換成明文
#
# 凱撒密碼 Wiki: [連結](https://zh.wikipedia.org/wiki/%E5%87%B1%E6%92%92%E5%AF%86%E7%A2%BC)

# %%
cipher = "KELLR SYTHRN!"
str1 = cipher.replace("K", "H")
str2 = str1.replace("S", "P")
str3 = str2.replace("R", "O")
print(str3)
# Out:
# HELLO PYTHON!

# %% [markdown]
# # str.isdecimal()
# 檢查一個字串内的字符是否都是數字
#
# ```python
# "123".isdecimal()
# # True
# ```

# %%
"123".isdecimal()
# True
# Out:
# True

# %% [markdown]
# # str.isdecimal()
# 檢查一個字串内的字符是否都是數字
#
# ```python
# "123".isdecimal()
# # True
# ```

# %% [markdown]
# # 更多關於字串的功能
#
# 可以參考 Python 官方網站關於字串的文件：[連結](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str)
#
# 在參考過 Python 管網的文件後，請嘗試寫一段程式碼，驗證一個你讀懂的字串方法

# %% [markdown]
# # 字串格式化（String Formatting）
#
# 在寫程式時爲了輸出字串而需要做大量的型別轉換很麻煩
#
# 若今天一個字串有一部分是不確定的，但是其他部分都有固定的格式，我們可使用 `%` 符號將資料填入指定的字串位置：
#
# ```python
# bmi = 22.724403484408533
#
# # 將 bmi 轉成浮點數（預設最多到小數點六位）
# print("我的BMI是：%f" % bmi)
# # 我的BMI是：22.724403
#
# # .2f 指定到小數點第二位
# print("我的BMI是：%.2f" % bmi)
# # 我的BMI是：22.72
#
# # 將 bmi 值轉成整數顯示
# print("我的BMI是：%i" % bmi)
# # 我的BMI是：22
#
# # 將 bmi 值轉換成字串顯示
# print("我的BMI是：%s" % bmi)
# # 我的BMI是：22.724403484408533，代表先將 bmi 轉成字串
# ```

# %%
bmi = 22.724403484408533

# 將 bmi 轉成浮點數（預設最多到小數點六位）
print("我的BMI是：%f" % bmi)
# 我的BMI是：22.724403

# .2f 指定到小數點第二位
print("我的BMI是：%.2f" % bmi)
# 我的BMI是：22.72

# 將 bmi 值轉成整數顯示
print("我的BMI是：%i" % bmi)
# 我的BMI是：22

# 將 bmi 值轉換成字串顯示
print("我的BMI是：%s" % bmi)
# 我的BMI是：22.724403484408533，代表先將 bmi 轉成字串
# Out:
# 我的BMI是：22.724403
# 我的BMI是：22.72
# 我的BMI是：22
# 我的BMI是：22.724403484408533

# %% [markdown]
# # 字串格式化（String Formatting）
#
# 若覺得 `%` 不夠直覺，也可以使用 `.format()` 方法將字串格式化，將放入 `.format()`内的值插入字串内`{}`的地方：
#
# ```python
# bmi = 22.724403484408533
#
# print("my bmi: {}".format(bmi))
# # my bmi: 22.724403484408533
# print("my bmi: {:f}".format(bmi))
# # my bmi: 22.724403
# print("my bmi: {:.2f}".format(bmi))
# # my bmi: 22.72
# print("my bmi: {:.0f}".format(bmi))
# # my bmi: 23
# ```

# %%
bmi = 22.724403484408533

print("my bmi: {}".format(bmi))
# my bmi: 22.724403484408533
print("my bmi: {:f}".format(bmi))
# my bmi: 22.724403
print("my bmi: {:.2f}".format(bmi))
# my bmi: 22.72
print("my bmi: {:.0f}".format(bmi),'!')
# my bmi: 23
# Out:
# my bmi: 22.724403484408533
# my bmi: 22.724403
# my bmi: 22.72
# my bmi: 23 !

# %% [markdown]
# # 字串格式化（String Formatting）
#
# 若覺得 `%` 不夠直覺，也可以使用 `.format()` 方法將字串格式化：
#
# ```python
# # 若是有多個值需要放入一個字串，可用 `{}` 表明被放入的地方
# # 再將值照順序放入 .format()
# '{} and {}'.format('spam', 'eggs')
# # spam and eggs
# '{0} and {1}'.format('spam', 'eggs')
# # spam and eggs
# '{1} and {0}'.format('spam', 'eggs')
# # eggs and spam
# 'This {food} is {adj}'.format(adj="yummy", food="pasta")
# # 'This pasta is yummy'
# ```

# %%
# 若是有多個值需要放入一個字串，可用 `{}` 表明被放入的地方
# 再將值照順序放入 .format() 
'{} and {}'.format('spam', 'eggs')
# spam and eggs
'{0} and {1}'.format('spam', 'eggs')
# spam and eggs
'{1} and {0}'.format('spam', 'eggs')
# eggs and spam
'This {food} is {adj}'.format(adj="yummy", food="pasta")
# 'This pasta is yummy'
# Out:
# 'This pasta is yummy'

# %% [markdown]
# # fstring （限 Python 3.6+）
#
# 比起 `%` 的不直覺，與 `.format()` 過度冗長，新版 Python 提供了 `fstring`，結合了上述兩種寫法的特性：
#
# ```python
# print(f"my bmi: {bmi}")
# # my bmi: 22.724403484408533
# print(f"my bmi: {bmi:f}")
# # my bmi: 22.724403
# print(f"my bmi: {bmi:.2f}")
# # my bmi: 22.72
# print(f"my bmi: {bmi:.0f}")
# # my bmi: 23
# ```

# %%
print(f"my bmi: {bmi}")
# my bmi: 22.724403484408533
print(f"my bmi: {bmi:f}")
# my bmi: 22.724403
print(f"my bmi: {bmi:.2f}")
# my bmi: 22.72
print(f"my bmi: {bmi:.0f}")
# my bmi: 23
# Out:
# my bmi: 22.724403484408533
# my bmi: 22.724403
# my bmi: 22.72
# my bmi: 23

# %% [markdown]
# # 流程控制與邏輯運算
#
# 電腦除了可以做數字的運算，也可以做**比較**
#
# ---
# # 比較運算子
#
# | 運算子 | 功能          | 實例    | 結果  |
# | :----: | :-----------: | :-----: | :---: |
# | ==    | 是否等於          | 3 == 3  | True |
# | !=      | 不等於     | 2 != 3 | True     |
# | >    |  是否大於 | 2 > 3 | False     |
# | <      | 是否小於   | 2 < 3  | True |
# | <=     | 小於等於 | 3 <= 3| True |
# | >=     | 大於等於 | 5 >=5 | True |
#
# ---
# # 比較運算子
#
# 這個結果的 **True** 和 **False** 代表什麼？
#
# ---
# # Boolean 布林值
#
# 另一種資料型別，電腦用來表示**成立**或**不成立**
#
# 布林值只有兩個值:
# ```python
# 	True #成立
# 	False #不成立
# ```

# %% [markdown]
# # 範例
#
# ```python
# 'hello' == 'hello'
# # True
# 47 > 47
# # False
# 47 >= 47
# # True
# ```

# %% [markdown]
# # 流程控制
#
# ![flow control](https://drive.google.com/uc?export=download&id=1Zj9Gfgc1QGkdzIM7ED-xKXiCX2BcOz3f)
#
# 當我們遇上程式需要針對不同選項執行不同結果時，我們需要學會用程式語言表達 Yes 和 No，以及邏輯上的分支點
#
# ---
# # if 陳述句
#
# 若 `if` 後面的比較式條件成立，也就是結果為 `True`，則執行子句中的程式碼：
#
# ```python
# num = 5
#
# if num > 5:
#     print("num is bigger than 5")
# ```

# %%
num = 5

if num > 5:
    print("num is bigger than 5")

# %% [markdown]
# # if...else 陳述句
#
# 若 `if` 關鍵字後面的比較式結果為 `False`，則忽略 `if` 子句，執行 `else` 的子句：
#
# ```python
# num = 5
#
# if num > 5:
#     print("num is bigger than 5")
# else:
#     print("num is smaller than or equal to 5")
# ```

# %%
num = 5

if num > 5:
    print("num is bigger than 5")
else:
    print("num is smaller than or equal to 5")
# Out:
# num is smaller than or equal to 5

# %% [markdown]
# # elif 陳述句
# 白話文就是指 "否則如果"
#
# 當邏輯判斷的可能性 / 選項超出兩種時，可用 `elif`：
#
# ```python
# num = 5
#
# if num > 5:
#     print("num is greater than 5")
# elif num < 5:
#     print("num is less than 5")
# else:
#     print("num is equal to 5")
# ```

# %%
num = 5

if num > 5:
    print("num is greater than 5")
elif num < 5:
    print("num is less than 5")
else:
    print("num is equal to 5")
# Out:
# num is equal to 5

# %% [markdown]
# # if...elif...else 陳述句
# - 只要 `if` 後面的條件結果是 `False`，便會看 `elif` 後面的條件
# - 若比較式結果為 `True`，便會執行 `elif` 的子句，不然便會繼續檢查下一個 `elif`
# - 若全部的比較式結果都是 `False`，則執行 `else` 底下的程式碼

# %% [markdown]
# # 小考 (Pop Quiz)
#
# 請使用選擇敘述撰寫一程式，讓使用者輸入一個正整數，然後判斷它是否為偶數（even）
#
# 範例輸入:
# ```
# 56
# ```
# 範例輸出:
# ```
# 56 is an even number.
# ```
# 範例輸入:
# ```
# 21
# ```
# 範例輸出:
# ```
# 21 is not an even number.
# ```

# %%
num=int(input())
print(type(num))
if num%2==0:
    print(f"{num} is an even number.") 
else:
    print(f"{num} is an odd number.")
# Out:
# <class 'int'>
# 33 is an odd number.

# %% [markdown]
# # 再次提醒
#
# - **若 `if` 後面的條件結果為 `True`, 便不會執行任何 `elif` 的後面的比較式**
#
# - **python 對縮排很敏感，任何 if, elif, 或 else 要執行的程式碼請記得要縮排**
#
# - **python 的縮排是四個空白符號(或是一個tab)**
#
#
# # 邏輯運算子
# 當你需要把多個比較式的結果串連起來時
#
# 像是條件一與條件二都必須成立:
# ```python
# if 條件一 == True 與 條件二 == True:
#     print("條件一與條件二都成立！")
# ```
#
# 要如何用 Python 程式碼表達這件事？
#
#
# # 邏輯運算子
# 當你需要把多個比較式連接起來時
#
# | 運算子 | 功能          | 實例    | 結果  |
# | :----: | :-----------: | :-----: | :---: |
# | and      | 而且        | True and True | True |
# | or       | 或許        | True or False | True |
# | not      | 反值        | not True | False |

# %% [markdown]
# # and truth table(真值表)
#
# | A | B | A and B |
# | :----: | :-----------: | :---: |
# | True      | True    |  True     |
# | True      | False   | False     |
# | False     | True    | False     |
# | False     | False   | False     |

# %% [markdown]
# # or truth table(真值表)
#
# | A | B | A or B |
# | :----: | :-----------: | :---: |
# | True      | True    |  True     |
# | True      | False   | True     |
# | False     | True    | True    |
# | False     | False   | False     |

# %% [markdown]
# # 隨堂練習 3
#
# 寫出一個判斷式，從報酬率判斷兩隻股票的走勢是否相同：
#
#
# **日報酬率 = (今日收盤價 - 昨日收盤價) / 昨日收盤價**
#
#
#
# ```python
# # 股票一報酬率
# stock_one_return = 0.1234
# # 股票二報酬率
# stock_two_return = -0.3456
#
# if _______:
#     print("兩者走勢相同")
# else:
#     print("兩者走勢不同")
# ```

# %%
# 股票一報酬率
stock_one_return = 0.1234
# 股票二報酬率
stock_two_return = -0.3456

if stock_one_return*stock_two_return>0:
    print("兩者走勢相同")
else:
    print("兩者走勢不同")
# Out:
# 兩者走勢不同

# %% [markdown]
# # 額外練習
#
# 用 Python 寫出一個支援四則運算的計算機
#
# ```python
# print("請輸入第一個數字：")
# first_num = input()
# print("請輸入第二個數字：")
# second_num = input()
# print("請輸入運算方式：")
# print("1)+ 2)- 3)* 4)/：")
# operation = input()
#
# if operation == ____:
#     print(_______________)
# ```

# %% [markdown]
# # 作業一：剪刀、石頭、布遊戲
#
# ![](https://drive.google.com/uc?export=download&id=1QQU8p6XTixh8Z36iOBf1EYfw4LC1yiKy)
#
# # 範例程式碼：
#
# ```python
# print("歡迎來到剪刀石頭布！ ")
# name = input("請輸入您的名稱：")
#
# player_hand = int(input(("請出拳： (1) 剪刀 (2) 石頭 (3) 布："))
# computer_hand = random.randint(1,3)
# # 把剩下的判斷輸贏寫完...
# ```
#
#
# # 挑戰
#
# 要如何能夠實作出讓電腦自動出拳的功能？
#
#
#
# # 隨機數 (Random)
# ```python
# # 匯入 random 模組的功能
# import random
# # 隨機回傳範圍 1 到 3 之間的某個整數
# print(random.randint(1,3))
# ```

# %%
import random

print("歡迎來到剪刀石頭布！ ")
#name = input("請輸入您的名稱：")
win = [[1,3], [2,1], [3,2]]
print("請出拳： (1) 剪刀 (2) 石頭 (3) 布：")
player_hand = int(input())
print(player_hand)
computer_hand = random.randint(1,3)
output=['剪刀','石頭','布']
print(f"你出{output[player_hand-1]}")
print(f"電腦出{output[computer_hand-1]}")
if computer_hand==player_hand:
    print('平手')
elif [computer_hand,player_hand] in win:
    print('電腦贏')
else:print('你贏')
# Out:
# 歡迎來到剪刀石頭布！
# 請出拳： (1) 剪刀 (2) 石頭 (3) 布：
# 1
# 你出剪刀
# 電腦出石頭
# 電腦贏

# %% [markdown]
# # 額外練習
#
# 打造一個完整版的凱撒密碼系統
#
# 參考網頁：[Cryptii](https://cryptii.com/pipes/caesar-cipher)
#
# ---
#
# 該系統必須具備：
#
# 1. 加密功能
#
# 給予一個明碼字串
#
# ```python
# message = "HELLO PYTHON"
# ```
#
# 最後你的程式應該能夠將該字串加密成：
#
# ```python
# "KHOOR SBWKRQ"
# ```
# ***爲了簡化問題，我們假設加密的偏移量是往左移 3 個字母**
#
# 2. 解密功能
#
# 給予一個被凱撒密碼加密過的字串：
#
# ```python
# cipher = "KHOOR SBWKRQ"
# ```
# 你的程式應該能夠將字串解密成：
#
# ```python
# "HELLO PYTHON"
# ```
#
# ---
#
# 詳細的運作過程可以參考：
#
# 凱撒密碼的 Wiki: [連結](https://zh.wikipedia.org/wiki/%E5%87%B1%E6%92%92%E5%AF%86%E7%A2%BC)

# %% [markdown]
# # 隨堂練習 1 解答
# ```python
# str1 = "123,456,789"
# float(str1.replace(",", ""))
# ```

# %% [markdown]
# # 隨堂練習 2 解答
#
# ```python
# cipher = "KELLR SYTHRN!"
# cipher.replace("K", "H").replace("S", "P").replace("R", "O")
# ```

# %% [markdown]
# # 隨堂練習 3 解答
#
# ```python
# # 股票一報酬率
# stock_one_return = 0.123
# # 股票二報酬率
# stock_two_return = -0.345
#
# if stock_one_return < 0 and stock_two_return < 0:
#     print("兩者走勢相同")
# elif stock_one_return > 0 and stock_two_return > 0:
#     print("兩者走勢相同")
# elif stock_one_return == 0 and stock_two_return == 0:
#     print("兩者走勢相同")
# else:
#     print("兩者走勢不同")
# ```
